# %%
pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in c:\dev\personal projects\speech recognition using emotions\.myenv\lib\site-packages (from kagglehub) (25.0)
# Collecting pyyaml (from kagglehub)
#   Downloading pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: requests in c:\dev\personal projects\speech recognition using emotions\.myenv\lib\site-packages (from kagglehub) (2.32.5)
# Collecting tqdm (from kagglehub)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\dev\personal projects\speech recognition using emotions\.myenv\lib\site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\dev\personal projects\speech recognition using emotions\.myenv\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\dev\personal projects\speech recognition using emotions\.myenv\lib\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\dev\personal projects\speech recognition using emotions\.myenv\lib\site-packages (from requests->kagglehub) (2025.11.12)
# Requirement already satisfied: colorama in c:\dev\personal projects\speech recognition using emotions\.myenv\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Downloading pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, pyyaml, kagglehub
#
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ------------- -------------------------- 1/3 [pyyaml]
#    -------------------------- ------------- 2/3 [kagglehub]
#    -------------------------- ------------- 2/3 [kagglehub]
#    -------------------------- ------------- 2/3 [kagglehub]
#    ---------------------------------------- 3/3 [kagglehub]
#
# Successfully installed kagglehub-0.3.13 pyyaml-6.0.3 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ejlok1/toronto-emotional-speech-set-tess")

print("Path to dataset files:", path)
# Out:
# Resuming download from 133169152 bytes (315402882 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/ejlok1/toronto-emotional-speech-set-tess?dataset_version_number=1 (133169152/448572034) bytes left.
# 100%|██████████| 428M/428M [03:06<00:00, 1.69MB/s]
# Extracting files...
# Path to dataset files: C:\Users\El3atty\.cache\kagglehub\datasets\ejlok1\toronto-emotional-speech-set-tess\versions\1

# %%
import torch

# %%
print(f"CUDA Available: {torch.cuda.is_available()}")
print(f"GPU Name: {torch.cuda.get_device_name(0)}")

# Test GPU operation
if torch.cuda.is_available():
    x = torch.randn(1000, 1000).cuda()
    y = torch.randn(1000, 1000).cuda()
    z = x @ y  # Matrix multiplication on GPU
    print(f"GPU test successful! Result on: {z.device}")
# Out:
# CUDA Available: True
# GPU Name: NVIDIA GeForce RTX 3050 Ti Laptop GPU
# GPU test successful! Result on: cuda:0
